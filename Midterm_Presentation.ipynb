# %%
import pandas as pd

# %%
data = pd.read_csv("ProductPriceIndex.csv")

# %%
data
# Out:
#             productname        date farmprice atlantaretail chicagoretail  \
# 0          Strawberries  2019-05-19     $1.16         $2.23         $1.70
# 1       Romaine Lettuce  2019-05-19     $0.35         $1.72         $2.00
# 2      Red Leaf Lettuce  2019-05-19     $0.32         $1.84         $1.84
# 3              Potatoes  2019-05-19     $1.50         $5.32         $5.14
# 4               Oranges  2019-05-19     $0.41         $1.42         $1.45
# ...                 ...         ...       ...           ...           ...
# 15761   Broccoli Crowns  1999-10-24     $0.29         $1.46         $0.00
# 15762  Broccoli Bunches  1999-10-24     $0.23         $1.21         $0.00
# 15763       Cauliflower  1999-10-24     $0.19         $1.01         $0.00
# 15764           Carrots  1999-10-24     $0.12         $0.64         $0.00
# 15765        Cantaloupe  1999-10-24     $0.21         $0.54         $0.00
#
#       losangelesretail newyorkretail averagespread
# ...

# %%
data.head(2)
# Out:
#        productname        date farmprice atlantaretail chicagoretail  \
# 0     Strawberries  2019-05-19     $1.16         $2.23         $1.70
# 1  Romaine Lettuce  2019-05-19     $0.35         $1.72         $2.00
#
#   losangelesretail newyorkretail averagespread
# 0            $1.99         $2.54        82.33%
# 1            $1.69         $1.99       428.57%

# %%
data.head(10)
# Out:
#           productname        date farmprice atlantaretail chicagoretail  \
# 0        Strawberries  2019-05-19     $1.16         $2.23         $1.70
# 1     Romaine Lettuce  2019-05-19     $0.35         $1.72         $2.00
# 2    Red Leaf Lettuce  2019-05-19     $0.32         $1.84         $1.84
# 3            Potatoes  2019-05-19     $1.50         $5.32         $5.14
# 4             Oranges  2019-05-19     $0.41         $1.42         $1.45
# 5     Iceberg Lettuce  2019-05-19     $0.35         $1.39         $1.46
# 6  Green Leaf Lettuce  2019-05-19     $0.31         $1.72         $1.70
# 7              Celery  2019-05-19     $2.83         $1.89         $2.36
# 8         Cauliflower  2019-05-19     $1.22         $3.24         $4.35
# 9             Carrots  2019-05-19     $0.24         $0.95         $0.95
#
#   losangelesretail newyorkretail averagespread
# 0            $1.99         $2.54        82.33%
# 1            $1.69         $1.99       428.57%
# ...

# %%
data.sample(10)
# Out:
#               productname        date farmprice atlantaretail chicagoretail  \
# 3081               Celery  2015-05-24     $0.63         $1.66         $1.63
# 2976          Cauliflower  2015-06-28     $0.67         $3.23         $3.06
# 4811          Cauliflower  2013-02-03     $0.70         $3.64         $3.69
# 13605  Green Leaf Lettuce  2002-07-28     $0.18         $1.16         $1.29
# 13231             Carrots  2003-01-05     $0.21         $0.73         $0.82
# 8179          Cauliflower  2008-11-30     $0.40         $1.21         $1.45
# 472    Green Leaf Lettuce  2018-09-23     $0.56         $1.59         $1.71
# 4069          Cauliflower  2014-02-16     $0.80         $2.80         $3.28
# 9500      Broccoli Crowns  2007-06-17     $0.27         $1.63         $1.53
# 14082             Oranges  2001-12-16     $0.10         $0.35         $0.31
#
#       losangelesretail newyorkretail averagespread
# 3081             $1.72         $2.04       179.76%
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15766 entries, 0 to 15765
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   productname       15766 non-null  object
#  1   date              15766 non-null  object
#  2   farmprice         15766 non-null  object
#  3   atlantaretail     15766 non-null  object
#  4   chicagoretail     15766 non-null  object
#  5   losangelesretail  15766 non-null  object
#  6   newyorkretail     15766 non-null  object
#  7   averagespread     15766 non-null  object
# dtypes: object(8)
# memory usage: 985.5+ KB

# %%
data.describe()
# Out:
#             productname        date farmprice atlantaretail chicagoretail  \
# count             15766       15766     15766         15766         15766
# unique               22        1019       316           528           458
# top     Broccoli Crowns  2012-08-12     $0.21         $1.32         $0.00
# freq               1017          37       408           243          1103
#
#        losangelesretail newyorkretail averagespread
# count             15766         15766         15766
# unique              436           406         10492
# top               $0.99         $1.99       250.00%
# freq                475           547            37

# %%
data.describe(include='all')
# Out:
#             productname        date farmprice atlantaretail chicagoretail  \
# count             15766       15766     15766         15766         15766
# unique               22        1019       316           528           458
# top     Broccoli Crowns  2012-08-12     $0.21         $1.32         $0.00
# freq               1017          37       408           243          1103
#
#        losangelesretail newyorkretail averagespread
# count             15766         15766         15766
# unique              436           406         10492
# top               $0.99         $1.99       250.00%
# freq                475           547            37

# %% [markdown]
# # Unique values for "date" and "farmprice" charts

# %%
data['date'].value_counts()
# Out:
# date
# 2012-08-12    37
# 2014-08-17    35
# 2012-05-13    32
# 2014-08-03    31
# 2012-04-08    27
#               ..
# 2018-06-07     1
# 2012-07-02     1
# 2018-09-12     1
# 2018-09-26     1
# 2001-06-11     1
# Name: count, Length: 1019, dtype: int64

# %%
data['farmprice'].value_counts()
# Out:
# farmprice
# $0.21    408
# $0.30    400
# $0.29    397
# $0.26    344
# $0.27    341
#         ...
# $3.55      1
# $3.40      1
# $2.37      1
# $2.84      1
# $2.52      1
# Name: count, Length: 316, dtype: int64

# %% [markdown]
# # Top 10 most frequent values in "date" and "farmprice" columns

# %%
data['date'].value_counts()[:10]
# Out:
# date
# 2012-08-12    37
# 2014-08-17    35
# 2012-05-13    32
# 2014-08-03    31
# 2012-04-08    27
# 2014-08-10    24
# 2004-06-06    22
# 2017-09-10    22
# 2008-06-29    21
# 2018-08-05    21
# Name: count, dtype: int64

# %%
data['productname'].value_counts()[:10]
# Out:
# productname
# Broccoli Crowns       1017
# Cauliflower           1016
# Green Leaf Lettuce    1015
# Red Leaf Lettuce      1014
# Iceberg Lettuce       1014
# Carrots               1013
# Romaine Lettuce       1013
# Celery                1012
# Broccoli Bunches       973
# Strawberries           973
# Name: count, dtype: int64

# %% [markdown]
# # I have noticed that word 'Strawberries' appears (973 times).It is less than others.

# %% [markdown]
# # Let's see general price infornation of certain products in New York state and Los Angeles in 1999 and 2019

# %%
data.head(10)[['productname','date','newyorkretail']].value_counts()[:10].plot(kind='pie', title= 'Produce price in New York stores in 2019')
# Out:
# <Axes: title={'center': 'Produce price in New York stores in 2019'}, ylabel='count'>

# %%
data.head(10)[['productname','date','losangelesretail']].value_counts()[:10].plot(kind='pie', title= 'Produce price in Los Angeles markets in 2019')
# Out:
# <Axes: title={'center': 'Produce price in Los Angeles markets in 2019'}, ylabel='count'>

# %% [markdown]
# # Now lets see 1999 year information

# %%
data.tail(10)[['productname','date','newyorkretail']].value_counts()[:10].plot(kind='barh', title= 'Produce price in New York stores in 1999')
# Out:
# <Axes: title={'center': 'Produce price in New York stores in 1999'}, ylabel='productname,date,newyorkretail'>

# %%
data.tail(10)[['productname','date','losangelesretail']].value_counts()[:10].plot(kind='barh',title= 'Produce price in Los Angeles markets in 1999')
# Out:
# <Axes: title={'center': 'Produce price in Los Angeles markets in 1999'}, ylabel='productname,date,losangelesretail'>

# %%
data['productname']
# Out:
# 0            Strawberries
# 1         Romaine Lettuce
# 2        Red Leaf Lettuce
# 3                Potatoes
# 4                 Oranges
#                ...
# 15761     Broccoli Crowns
# 15762    Broccoli Bunches
# 15763         Cauliflower
# 15764             Carrots
# 15765          Cantaloupe
# Name: productname, Length: 15766, dtype: object

# %% [markdown]
# # Decided to focus more on one specific product - "Strawberries"

# %%
data.iloc[0]
# Out:
# productname         Strawberries
# date                  2019-05-19
# farmprice                  $1.16
# atlantaretail              $2.23
# chicagoretail              $1.70
# losangelesretail           $1.99
# newyorkretail              $2.54
# averagespread             82.33%
# Name: 0, dtype: object

# %%
filter= data['productname'] == 'Strawberries'

# %%
subset = data.loc[filter]

# %%
subset
# Out:
#         productname        date farmprice atlantaretail chicagoretail  \
# 0      Strawberries  2019-05-19     $1.16         $2.23         $1.70
# 13     Strawberries  2019-05-12     $0.91         $2.67         $1.89
# 27     Strawberries  2019-05-05     $0.58         $2.42         $1.89
# 39     Strawberries  2019-04-28     $0.58         $2.79         $1.95
# 52     Strawberries  2019-04-21     $0.69         $2.92         $2.04
# ...             ...         ...       ...           ...           ...
# 15657  Strawberries  1999-12-26     $1.25         $2.97         $0.00
# 15709  Strawberries  1999-11-21     $1.22         $3.34         $0.00
# 15732  Strawberries  1999-11-14     $1.22         $3.34         $0.00
# 15741  Strawberries  1999-11-07     $1.22         $3.09         $0.00
# 15752  Strawberries  1999-10-31     $0.84         $2.49         $0.00
#
#       losangelesretail newyorkretail averagespread
# 0                $1.99         $2.54        82.33%
# ...

# %% [markdown]
# # It appear that there are 973 rows with strawberries price

# %% [markdown]
# # Using new code to compare "Strawberries' price on the farms and in New York state in 1999 and 2019

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x = data.head(10)['farmprice']
y = data.head(10)['newyorkretail']

# %%
plt.scatter(x, y)
plt.xlabel('farmprice')
plt.ylabel('newyorkretail')
plt.title('Comparing Strawberries price on farm and in New York state in 2019')
# Out:
# Text(0.5, 1.0, 'Comparing Strawberries price on farm and in New York state in 2019')

# %%
x = data.tail(10)['farmprice']
y = data.tail(10)['newyorkretail']

# %%
plt.scatter(x,y)
plt.xlabel('farmprice')
plt.ylabel('newyorkretail')
plt.title('Comparing Strawberries price on farm and in New York state in 1999')
# Out:
# Text(0.5, 1.0, 'Comparing Strawberries price on farm and in New York state in 1999')
